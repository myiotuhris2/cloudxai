# %%
1+1
# Out:
# 2

# %%
import math
math.log10(10)
# Out:
# 1.0

# %%
math.log(2.7)
# Out:
# 0.9932517730102834

# %%
mid=0.5
hi=1
lo=0
for i in range(10):
    if 10**mid>5:
        hi=mid
    else:
        lo=mid
    mid=(hi+lo)/2
    print(f"hi: {hi}, lo: {lo}")
    print(mid)
    print(10**mid)
# Out:
# hi: 1, lo: 0.5
# 0.75
# 5.623413251903491
# hi: 0.75, lo: 0.5
# 0.625
# 4.216965034285822
# hi: 0.75, lo: 0.625
# 0.6875
# 4.869675251658631
# hi: 0.75, lo: 0.6875
# 0.71875
# 5.232991146814947
# hi: 0.71875, lo: 0.6875
# 0.703125
# 5.0480657166674705
# hi: 0.703125, lo: 0.6875
# 0.6953125
# 4.958068241684655
# hi: 0.703125, lo: 0.6953125
# 0.69921875
# 5.002864610575233
# hi: 0.69921875, lo: 0.6953125
# 0.697265625
# 4.980416061248411
# hi: 0.69921875, lo: 0.697265625
# 0.6982421875
# 4.991627716362687
# hi: 0.69921875, lo: 0.6982421875
# 0.69873046875
# 4.997243005033611
